# %%
import requests

url = "http://data4library.kr/api/loanItemSrch?authKey=1bece1ac39751f27906480adcb5922a5b83e9a2809338cc4bbea7633f397b36c&startDt=2023-08-01&endDt=2023-08-31&age=20&dtl_region=31070&format='JSON'"

r = requests.get(url)

data = r.json()

print(data)
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN  세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0  9.79117E+12      NaN    0  NaN  199.1     1     0  2023-03-30
# 1  9.79113E+12      NaN    1  NaN  373.7     1     0  2023-03-30
# 2  9.79117E+12      NaN    1  NaN  376.6     1     0  2023-03-30
# 3  9.79117E+12      NaN    4  NaN  813.7     1     0  2023-03-30
# 4  9.78895E+12      NaN    0  NaN  813.7     1     0  2023-03-30

# %%
books=[]

for d in data['response']['docs']:
    books.append(d['doc'])
    
print(books)
# Out:
#    번호                                도서명              저자   출판사  발행년도  \
# 0   1                           세이노의 가르침          세이노 지음   데이원  2023
# 1   2                         서울대생의 비밀과외  소린TV,안소린 [공]지음  다산에듀  2023
# 2   3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음   센시오  2023
# 3   4                        당연하게도 나는 너를          이꽃님 지음  우리학교  2023
# 4   5                             고요한 우연          김수빈 지음  문학동네  2023
#
#           ISBN
# 0  9.79117E+12
# 1  9.79113E+12
# 2  9.79117E+12
# 3  9.79117E+12
# 4  9.78895E+12

# %%
import pandas as pd

books_df = pd.DataFrame(books)
print(books_df)

# %%
books = books_df[['no','ranking','bookname','authors','publisher','publication_year','isbn13']]
books.head()

# %%
books_df.loc[[0,2],['bookname','authors']]
books_df.loc[0:2,'bookname':'publisher']
books_df.loc[:,'no':'publisher']
# Out:
#             번호                                도서명              저자     출판사  \
# 0            1                           세이노의 가르침          세이노 지음     데이원
# 1            2                         서울대생의 비밀과외  소린TV,안소린 [공]지음    다산에듀
# 2            3  (현직 고등학교 선생님들이 직접 고른) 생기부 필독서 100        주경아 외 지음     센시오
# 3            4                        당연하게도 나는 너를          이꽃님 지음    우리학교
# 4            5                             고요한 우연          김수빈 지음    문학동네
# ...        ...                                ...             ...     ...
# 207137  227830                          중국사 103장면      중국역사연구회 지음  한겨레신문사
# 207138  227831                              컷종합사전           편집부 편   송정문화사
# 207139  227832                               삼국지1           나관중 저     북뱅크
# 207140  227833                        사랑할 때와 죽을 때     E.M. 레마르크 저     현암사
# 207141  227834                      고교생이 알아야 할 소설           구인환 저   삼성미디어
#
#         발행년도         ISBN
# 0       2023  9.79117E+12
# ...

# %%
book_name = '아버지의 해방일지'
url = 'https://www.yes24.com/Product/Search?domain=BOOK&query={}'
r = requests.get(url.format(book_name))

print(r.text)   # HTML 출력
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 달러구트 꿈 백화점 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %% [markdown]
# F12로 개발자도구 켜서 HTML 태그 찾기

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')  # 파싱할 HTML, 파싱할 파서 (파서 : 입력데이터를 받아 데이터 구조를 만드는 소프트웨어 라이브러리 이걸 이용해 데이터 구조를 만들어 주는 것을 파싱)
# html.parser는 파이썬기본 내장 HTML 파서

print(soup)
# Out:
# <!DOCTYPE html >
#
# <html lang="ko">
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title> 달러구트 꿈 백화점 - 예스24</title>
# <meta content="예스24" name="title"/>
# <meta content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" name="keywords"/>
# <link href="//www.yes24.com/OpensearchDescription.xml" rel="search" title="YES24" type="application/opensearchdescription+xml"/>
# ...

# %%
#태그 위치 찾기
prd_link = soup.find('a', attrs={'class':'gd_name'})

print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/91065309" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '달러구트 꿈 백화점', '91065309', '0');">달러구트 꿈 백화점 </a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/91065309

# %%
#상세페이지
detail_url = 'http://www.yes24.com'+prd_link['href']

detail_r = requests.get(detail_url)

print(detail_r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://www.yes24.com/Product/Goods/91065309"> <link rel="alternate" media="only screen and(max-width: 640px)"  href="https://m.yes24.com/Goods/Detail/91065309">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>달러구트 꿈 백화점  - 예스24 </title>
#
#
# <meta name="title" content="달러구트 꿈 백화점 "/>
# <meta name="author" content="이미예 저" />
#
# ...

# %% [markdown]
# 마우스 오른쪽 -> 검사 -> select -> 쪽수
#
# 태그
# <div id="infoset_specific" class="gd_infoSet infoSet_noLine">

# %%
detail_soup = BeautifulSoup(detail_r.text, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html >
#
# <html lang="ko">
# <head><link href="https://www.yes24.com/Product/Goods/91065309" rel="canonical"/> <link href="https://m.yes24.com/Goods/Detail/91065309" media="only screen and(max-width: 640px)" rel="alternate"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title>달러구트 꿈 백화점  - 예스24 </title>
# <meta content="달러구트 꿈 백화점 " name="title"/>
# <meta content="이미예 저" name="author"/>
# <meta content="주문하신 꿈은 매진입니다. 이미예 저. 팩토리나인. 판매가 12,420원(10% 할인). 포인트 690원(5% 적립). 여기는 잠들어야만 입장할 수 있는 ‘달러구트 꿈 백화점’입니다잠들어야만 입장할 수 있는 독특한 마을. 그곳에 들어온 잠든 손님들에게 가장 인..." name="description"/>
# ...

# %%
#div 태그에 id가 inofoset_specific인 것 찾기
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

print(prd_detail)
# Out:
# <div class="gd_infoSet infoSet_noLine" id="infoset_specific">
# <div class="tm_infoSet">
# <h4 class="tit_txt">품목정보</h4>
# </div>
# <div class="infoSetCont_wrap">
# <div class="yesTb">
# <table class="tb_nor tb_vertical" summary="품목정보 국내도서, 외국도서 " width="100%">
# <caption>품목정보</caption>
# <colgroup>
# <col width="170"/>
# <col width="*"/>
# </colgroup>
# <tbody class="b_size">
# <tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 07월 08일</td>
# </tr>
# <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">300쪽 | 358g | 134*200*20mm</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791165341909</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1165341905</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <script type="text/javascript">
#         if ($("#infoset_specific table tbody tr").length == 0) {
#             $("#infoset_specific").remove();
# ...

# %%
# 테이블 태그 리스트로 가져오기 (tr 태그 안에있는것)
prd_tr_list = prd_detail.find_all('tr')

print(prd_tr_list)
# Out:
# [<tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 07월 08일</td>
# </tr>, <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">300쪽 | 358g | 134*200*20mm</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791165341909</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1165341905</td>
# </tr>]

# %%
# 태그안의 텍스트
for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
        page_td = tr.find('td').get_text()
        break

print(page_td)
# Out:
# 300쪽 | 358g | 134*200*20mm

# %%
print(page_td.split()[0])
# Out:
# 300쪽

# %%
#전체 도서의 쪽수 구하기 (코딩 쓰기)
def get_page_cnt(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

    # URL에 ISBN을 넣어 HTML 가져오기
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱

    # 검색 결과에서 해당 도서를 선택
    prd_info = soup.find('a', attrs={'class':'gd_name'})
    if prd_info == None:    # 도서 정보가 없으면 '' 리턴하고 함수 종료
        return ''
    
    # 도서 상세 페이지 가져오기
    detail_url = 'http://www.yes24.com'+prd_info['href']
    detail_r = requests.get(detail_url)
    soup = BeautifulSoup(detail_r.text, 'html.parser')

    # 상품 상세정보 div 선택
    prd_detail = soup.find('div', attrs={'id':'infoset_specific'})

    # 테이블에 있는 tr 태그 가져오기
    prd_tr_list = prd_detail.find_all('tr')
    
    # 쪽수가 들어 있는 th를 찾아 td에 담긴 값 반환
    for tr in prd_tr_list:
        if tr.find('th').get_text() == '쪽수, 무게, 크기':
            return tr.find('td').get_text().split()[0]
    return ''   # 쪽수 정보가 없으면 '' 리턴하고 함수 종료

# %%
# 데이터 프레임 행 혹은 열에 함수 적용하기 
top10_books = books.head(10)

def get_page_cnt2(row):
    isbn = row['ISBN']
    return get_page_cnt(isbn)

# %%
page_count = top10_books.apply(get_page_cnt2, axis=1)

print(page_count)

# %%
#merge() 함수
